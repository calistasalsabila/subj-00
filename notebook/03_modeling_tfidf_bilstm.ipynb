# %% [markdown]
# ## 3. Modeling TF-IDF x BILSTM

# %% [markdown]
# ### 3.1 Importing the Libraries

# %%
import os
import pathlib
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import ( Dense, Embedding, Bidirectional, LSTM, Input, Concatenate, Dropout)
# Out:
# 2026-01-18 13:58:49.917559: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-18 13:58:49.967031: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-18 13:58:51.235124: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### 3.2 Define the Parameter

# %%
VOCAB_SIZE = 5000
TFIDF_FEATURES = 5000
MAX_LEN = 200
MODEL_SAVE_PATH = "../models/bilstm_model_raw.keras"

# %% [markdown]
# ### 3.2 Load the Dataset

# %%
# Training
X_train_pad   = pickle.load(open("../dataset/processed/02_after_FE_raw/X_train_pad.pkl", "rb"))
X_train_tfidf = pickle.load(open("../dataset/processed/02_after_FE_raw/X_train_tfidf.pkl", "rb"))
y_train       = pickle.load(open("../dataset/processed/02_after_FE_raw/y_train.pkl", "rb"))

# Validation
X_val_pad     = pickle.load(open("../dataset/processed/02_after_FE_raw/X_val_pad.pkl", "rb"))
X_val_tfidf   = pickle.load(open("../dataset/processed/02_after_FE_raw/X_val_tfidf.pkl", "rb"))
y_val         = pickle.load(open("../dataset/processed/02_after_FE_raw/y_val.pkl", "rb"))

# Test
X_test_pad    = pickle.load(open("../dataset/processed/02_after_FE_raw/X_test_pad.pkl", "rb"))
X_test_tfidf  = pickle.load(open("../dataset/processed/02_after_FE_raw/X_test_tfidf.pkl", "rb"))
y_test        = pickle.load(open("../dataset/processed/02_after_FE_raw/y_test.pkl", "rb"))

# %% [markdown]
# ### 3.3 Konversi Data Type

# %%
# Input Sequence (X_pad)
X_train_pad = np.array(X_train_pad, dtype='int32')
X_val_pad   = np.array(X_val_pad, dtype='int32')   
X_test_pad  = np.array(X_test_pad, dtype='int32')

# Input TFIDF and Label 
X_train_tfidf = np.array(X_train_tfidf, dtype='float32')
X_val_tfidf   = np.array(X_val_tfidf, dtype='float32') 
X_test_tfidf  = np.array(X_test_tfidf, dtype='float32')

y_train = np.array(y_train, dtype='float32')
y_val   = np.array(y_val, dtype='float32')          
y_test  = np.array(y_test, dtype='float32')

# %% [markdown]
# ### 3.4 Check Array Dimension

# %%
print(f"Shape X_train_pad: {X_train_pad.shape}")
print(f"Shape X_train_tfidf: {X_train_tfidf.shape}")
print(f"Shape y_train: {y_train.shape}")
print(f"Shape y_test: {y_test.shape}")
# Out:
# Shape X_train_pad: (30806, 200)
# Shape X_train_tfidf: (30806, 5000)
# Shape y_train: (30806,)
# Shape y_test: (2089,)

# %%
# Assertion Check
assert X_train_pad.shape[0] == X_train_tfidf.shape[0] == y_train.shape[0], \
    "Mismatch: jumlah sample antara sequence, tfidf, dan label tidak sama!"

assert X_test_pad.shape[0] == X_test_tfidf.shape[0] == y_test.shape[0], \
    "Mismatch: jumlah sample test tidak sama!"

# %% [markdown]
# ### 3.4 Build BiLSTM Model with TF-IDF

# %%
# Sequence Branch
input_seq = Input(shape=(MAX_LEN,), name='input_sequence')

x = Embedding(input_dim=VOCAB_SIZE, output_dim=64)(input_seq) 

# On x-axis, add kernel_regularizer = l2(0.01)
x = Bidirectional(LSTM(32, kernel_regularizer=l2(0.01)))(x)
x = Dropout(0.5)(x) 


# TF-IDF Branch
input_tfidf = Input(shape=(TFIDF_FEATURES,), name='input_tfidf') 

# On y-axis, add kernel_regularizer = l2(0.01)
y = Dense(16, activation='relu', kernel_regularizer=l2(0.01))(input_tfidf)
y = Dropout(0.5)(y) 


# Concate
combined = Concatenate()([x, y])

# Output layer
# On z-axis, add kernel_regularizer = l2(0.01)
z = Dense(32, activation="relu", kernel_regularizer=l2(0.01))(combined)
z = Dropout(0.5)(z) 

output_layer = Dense(1, activation="sigmoid")(z)

# Define model
model = Model(inputs=[input_seq, input_tfidf], outputs=output_layer)

# Reduce the Learning Rate (add zero to one) to make it smooth
optimizer = AdamW(learning_rate=0.00001, weight_decay=0.004) 

model.compile(
    loss='binary_crossentropy',
    optimizer=optimizer, 
    metrics=['accuracy']
)

print(model.summary())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768719557.924235   81626 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4132 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_sequence      │ (None, 200)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 200, 64)   │    320,000 │ input_sequence[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_tfidf         │ (None, 5000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 64)        │     24,832 │ embedding[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │     80,016 │ input_tfidf[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 80)        │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      2,592 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         33 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 427,473 (1.63 MB)
#  Trainable params: 427,473 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### 3.5 Define Callbacks

# %%
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=3, 
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# ### 3.6 Training

# %%
history = model.fit(
    [X_train_pad, X_train_tfidf],
    y_train,
    validation_data=([X_val_pad, X_val_tfidf], y_val), # Use explicit validation data
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 2026-01-18 13:59:31.112769: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91800
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.5436 - loss: 3.0394 - val_accuracy: 0.7165 - val_loss: 2.9066
# Epoch 2/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.6172 - loss: 2.7924 - val_accuracy: 0.8693 - val_loss: 2.6752
# Epoch 3/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.6871 - loss: 2.5799 - val_accuracy: 0.9646 - val_loss: 2.4705
# Epoch 4/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.7540 - loss: 2.3909 - val_accuracy: 0.9708 - val_loss: 2.2709
# Epoch 5/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.8407 - loss: 2.1503 - val_accuracy: 0.9157 - val_loss: 1.8742
# Epoch 6/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9178 - loss: 1.8927 - val_accuracy: 0.9210 - val_loss: 1.6284
# Epoch 7/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9084 - loss: 1.6938 - val_accuracy: 0.8798 - val_loss: 1.5045
# Epoch 8/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9206 - loss: 1.5438 - val_accuracy: 0.8803 - val_loss: 1.4027
# Epoch 9/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9321 - loss: 1.4232 - val_accuracy: 0.8702 - val_loss: 1.3395
# Epoch 10/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9405 - loss: 1.3196 - val_accuracy: 0.9660 - val_loss: 1.1502
# Epoch 11/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9442 - loss: 1.2349 - val_accuracy: 0.9114 - val_loss: 1.1405
# Epoch 12/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9501 - loss: 1.1516 - val_accuracy: 0.9425 - val_loss: 1.0430
# Epoch 13/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9550 - loss: 1.0741 - val_accuracy: 0.9511 - val_loss: 0.9770
# Epoch 14/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9582 - loss: 1.0073 - val_accuracy: 0.9507 - val_loss: 0.9216
# Epoch 15/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9589 - loss: 0.9476 - val_accuracy: 0.9435 - val_loss: 0.8788
# Epoch 16/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9605 - loss: 0.8894 - val_accuracy: 0.9440 - val_loss: 0.8308
# Epoch 17/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9625 - loss: 0.8333 - val_accuracy: 0.9219 - val_loss: 0.8255
# Epoch 18/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9671 - loss: 0.7835 - val_accuracy: 0.9650 - val_loss: 0.7241
# Epoch 19/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9670 - loss: 0.7384 - val_accuracy: 0.9358 - val_loss: 0.7235
# Epoch 20/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9664 - loss: 0.7012 - val_accuracy: 0.9550 - val_loss: 0.6628
# Epoch 21/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9693 - loss: 0.6601 - val_accuracy: 0.9435 - val_loss: 0.6448
# Epoch 22/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9661 - loss: 0.6319 - val_accuracy: 0.9306 - val_loss: 0.6421
# Epoch 23/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9725 - loss: 0.5911 - val_accuracy: 0.9511 - val_loss: 0.5801
# Epoch 24/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9726 - loss: 0.5629 - val_accuracy: 0.9406 - val_loss: 0.5693
# Epoch 25/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9738 - loss: 0.5324 - val_accuracy: 0.9468 - val_loss: 0.5383
# Epoch 26/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9742 - loss: 0.5087 - val_accuracy: 0.9464 - val_loss: 0.5187
# Epoch 27/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9738 - loss: 0.4893 - val_accuracy: 0.9622 - val_loss: 0.4848
# Epoch 28/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9751 - loss: 0.4690 - val_accuracy: 0.9564 - val_loss: 0.4763
# Epoch 29/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9765 - loss: 0.4470 - val_accuracy: 0.9574 - val_loss: 0.4631
# Epoch 30/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9759 - loss: 0.4304 - val_accuracy: 0.9483 - val_loss: 0.4556
# Epoch 31/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9766 - loss: 0.4143 - val_accuracy: 0.9559 - val_loss: 0.4377
# Epoch 32/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9767 - loss: 0.4042 - val_accuracy: 0.9545 - val_loss: 0.4285
# Epoch 33/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9784 - loss: 0.3871 - val_accuracy: 0.9526 - val_loss: 0.4172
# Epoch 34/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9773 - loss: 0.3786 - val_accuracy: 0.9612 - val_loss: 0.4003
# Epoch 35/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9794 - loss: 0.3662 - val_accuracy: 0.9579 - val_loss: 0.3955
# Epoch 36/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9798 - loss: 0.3536 - val_accuracy: 0.9555 - val_loss: 0.3925
# Epoch 37/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9766 - loss: 0.3558 - val_accuracy: 0.9483 - val_loss: 0.3936
# Epoch 38/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9805 - loss: 0.3394 - val_accuracy: 0.9583 - val_loss: 0.3747
# Epoch 39/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9810 - loss: 0.3318 - val_accuracy: 0.9535 - val_loss: 0.3767
# Epoch 40/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9816 - loss: 0.3266 - val_accuracy: 0.9473 - val_loss: 0.3824
# Epoch 41/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9783 - loss: 0.3233 - val_accuracy: 0.9531 - val_loss: 0.3666
# Epoch 42/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9794 - loss: 0.3186 - val_accuracy: 0.9545 - val_loss: 0.3589
# Epoch 43/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9821 - loss: 0.3073 - val_accuracy: 0.9497 - val_loss: 0.3628
# Epoch 44/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9804 - loss: 0.3072 - val_accuracy: 0.9550 - val_loss: 0.3533
# Epoch 45/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9827 - loss: 0.3001 - val_accuracy: 0.9588 - val_loss: 0.3456
# Epoch 46/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9830 - loss: 0.2944 - val_accuracy: 0.9598 - val_loss: 0.3416
# Epoch 47/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9793 - loss: 0.2995 - val_accuracy: 0.9277 - val_loss: 0.4013
# Epoch 48/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9829 - loss: 0.2896 - val_accuracy: 0.9540 - val_loss: 0.3426
# Epoch 49/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9833 - loss: 0.2842 - val_accuracy: 0.9473 - val_loss: 0.3514
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %% [markdown]
# ### 3.7 Evaluation

# %%
loss, acc = model.evaluate([X_test_pad, X_test_tfidf], y_test, verbose=1)
print(f"\nAkurasi Test (BiLSTM + TF-IDF): {acc:.4f}")
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9622 - loss: 0.3316
#
# Akurasi Test (BiLSTM + TF-IDF): 0.9622

# %%
if 'y_pred' not in locals():
    y_pred_prob = model.predict([X_test_pad, X_test_tfidf], verbose=0)
    y_pred = (y_pred_prob > 0.5).astype(int)

acc  = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec  = recall_score(y_test, y_pred, zero_division=0)
f1   = f1_score(y_test, y_pred, zero_division=0)

print("\n" + "="*40)
print("   DETAIL EVALUASI: BiLSTM + TF-IDF")
print("="*40)
print(f"Akurasi   : {acc:.4f}")
print(f"Presisi   : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"F1-Score  : {f1:.4f}")
print("="*40)
# Out:
# ========================================
#    DETAIL EVALUASI: BiLSTM + TF-IDF
# ========================================
# Akurasi   : 0.9622
# Presisi   : 0.7143
# Recall    : 0.8589
# F1-Score  : 0.7799
# ========================================

# %% [markdown]
# #### 3.7.1 Training and Validation Loss

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss (BiLSTM)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 3.7.2 Confusion Matrix

# %%
y_pred_prob = model.predict([X_test_pad, X_test_tfidf])
y_pred = (y_pred_prob > 0.5).astype(int)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Hoax', 'Hoax'],
            yticklabels=['Non-Hoax', 'Hoax'])
plt.title('Confusion Matrix (BiLSTM)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(y_test, y_pred, target_names=['Non-Hoax', 'Hoax']))
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#               precision    recall  f1-score   support
#
#     Non-Hoax       0.99      0.97      0.98      1926
#         Hoax       0.71      0.86      0.78       163
#
#     accuracy                           0.96      2089
#    macro avg       0.85      0.91      0.88      2089
# weighted avg       0.97      0.96      0.96      2089

# %% [markdown]
# ### 3.8 Save Model

# %%
save_dir = pathlib.Path(MODEL_SAVE_PATH).parent 

os.makedirs(save_dir, exist_ok=True)
model.save(MODEL_SAVE_PATH)
print("Model saved to:", MODEL_SAVE_PATH)
# Out:
# Model saved to: ../models/bilstm_model_raw.keras

# %% [markdown]
# ### 3.9 Addition

# %%
best_epoch_index = np.argmin(history.history['val_loss'])
best_val_loss = history.history['val_loss'][best_epoch_index]

print(f"Model mulai menghafal sekitar epoch: {best_epoch_index + 1}")
print(f"Validation Loss terendah (Best Epoch): {best_val_loss:.4f}")
# Out:
# Model mulai menghafal sekitar epoch: 46
# Validation Loss terendah (Best Epoch): 0.3416
