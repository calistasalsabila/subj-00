# %% [markdown]
# ## 3. Modeling TF-IDF x LSTM

# %% [markdown]
# ### 3.1 Importing the Libraries

# %%
import pickle
import os 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns 

from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Dense, Embedding, LSTM, Input, Concatenate, Dropout)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import AdamW 
from tensorflow.keras.regularizers import l2
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
# Out:
# 2026-01-18 14:27:30.766824: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-18 14:27:30.867211: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-18 14:27:33.563170: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ### 3.2 Define the Parameter

# %%
VOCAB_SIZE = 5000
TFIDF_FEATURES = 5000
MAX_LEN = 200
MODEL_SAVE_PATH = "../models/lstm_model_raw.keras"

# %% [markdown]
# ### 3.2 Load the Dataset

# %%
# Training
X_train_pad   = pickle.load(open("../dataset/processed/02_after_FE_raw/X_train_pad.pkl", "rb"))
X_train_tfidf = pickle.load(open("../dataset/processed/02_after_FE_raw/X_train_tfidf.pkl", "rb"))
y_train       = pickle.load(open("../dataset/processed/02_after_FE_raw/y_train.pkl", "rb"))

# Validation
X_val_pad     = pickle.load(open("../dataset/processed/02_after_FE_raw/X_val_pad.pkl", "rb"))
X_val_tfidf   = pickle.load(open("../dataset/processed/02_after_FE_raw/X_val_tfidf.pkl", "rb"))
y_val         = pickle.load(open("../dataset/processed/02_after_FE_raw/y_val.pkl", "rb"))

# Test
X_test_pad    = pickle.load(open("../dataset/processed/02_after_FE_raw/X_test_pad.pkl", "rb"))
X_test_tfidf  = pickle.load(open("../dataset/processed/02_after_FE_raw/X_test_tfidf.pkl", "rb"))
y_test        = pickle.load(open("../dataset/processed/02_after_FE_raw/y_test.pkl", "rb"))

# %% [markdown]
# ### 3.3 Konversi Data Type

# %%
# Input Sequence (X_pad) for Embedding Layer
X_train_pad = np.array(X_train_pad, dtype='int32')
X_val_pad   = np.array(X_val_pad, dtype='int32')   # BARU
X_test_pad  = np.array(X_test_pad, dtype='int32')

# Input TFIDF and Label
X_train_tfidf = np.array(X_train_tfidf, dtype='float32')
X_val_tfidf   = np.array(X_val_tfidf, dtype='float32') # BARU
X_test_tfidf  = np.array(X_test_tfidf, dtype='float32')

y_train = np.array(y_train, dtype='float32')
y_val   = np.array(y_val, dtype='float32')         # BARU
y_test  = np.array(y_test, dtype='float32')

# %% [markdown]
# ### 3.4 Check Array Dimension

# %%
print(f"Shape X_train_pad: {X_train_pad.shape}")
print(f"Shape X_train_tfidf: {X_train_tfidf.shape}")
print(f"Shape y_train: {y_train.shape}")
print(f"Shape y_test: {y_test.shape}")
# Out:
# Shape X_train_pad: (30806, 200)
# Shape X_train_tfidf: (30806, 5000)
# Shape y_train: (30806,)
# Shape y_test: (2089,)

# %%
# Assertion check
assert X_train_pad.shape[0] == X_train_tfidf.shape[0] == y_train.shape[0], \
    "Mismatch: jumlah sample antara sequence, tfidf, dan label tidak sama!"

assert X_test_pad.shape[0] == X_test_tfidf.shape[0] == y_test.shape[0], \
    "Mismatch: jumlah sample test tidak sama!"

# %% [markdown]
# ### 3.4 Build LSTM Model with TF-IDF

# %%
# Sequence Branch
input_seq = Input(shape=(MAX_LEN,), name='input_sequence')

x = Embedding(input_dim=VOCAB_SIZE, output_dim=64)(input_seq) 

# # On x-axis, add kernel_regularizer = l2(0.01)
x = LSTM(32, kernel_regularizer=l2(0.01))(x) 
x = Dropout(0.5)(x) 

# TF-IDF Branch
input_tfidf = Input(shape=(TFIDF_FEATURES,), name='input_tfidf') 

# # On y-axis, add kernel_regularizer = l2(0.01) in dense
y = Dense(16, activation='relu', kernel_regularizer=l2(0.01))(input_tfidf) 
y = Dropout(0.5)(y) 

# Concate
combined = Concatenate()([x, y])

# Combined Dense Layer
# On z-axis, add kernel_regularizer = l2(0.01)
z = Dense(32, activation="relu", kernel_regularizer=l2(0.01))(combined) 
z = Dropout(0.5)(z) 

output_layer = Dense(1, activation="sigmoid")(z)

# Define model
model = Model(inputs=[input_seq, input_tfidf], outputs=output_layer)

# Reduce the Learning Rate (add zero to one) to make it smooth
optimizer = AdamW(learning_rate=0.00001, weight_decay=0.004)

model.compile(
    loss='binary_crossentropy',
    optimizer=optimizer, 
    metrics=['accuracy']
)
print(model.summary())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768721255.816432   98545 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1200 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_sequence      │ (None, 200)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 200, 64)   │    320,000 │ input_sequence[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_tfidf         │ (None, 5000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │     12,416 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │     80,016 │ input_tfidf[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 32)        │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 48)        │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │      1,568 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         33 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 414,033 (1.58 MB)
#  Trainable params: 414,033 (1.58 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### 3.5 Define Callbacks

# %%
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=3, 
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# ### 3.6 Training

# %%
history = model.fit(
    [X_train_pad, X_train_tfidf],
    y_train,
    validation_data=([X_val_pad, X_val_tfidf], y_val), 
    epochs=100,
    batch_size=64,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 2026-01-18 14:27:42.651010: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91800
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - accuracy: 0.5302 - loss: 2.1646 - val_accuracy: 0.6121 - val_loss: 2.0718
# Epoch 2/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.6213 - loss: 1.9897 - val_accuracy: 0.7548 - val_loss: 1.9153
# Epoch 3/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7217 - loss: 1.8428 - val_accuracy: 0.8966 - val_loss: 1.7807
# Epoch 4/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8221 - loss: 1.6944 - val_accuracy: 0.7031 - val_loss: 1.7095
# Epoch 5/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.8474 - loss: 1.5258 - val_accuracy: 0.8103 - val_loss: 1.5702
# Epoch 6/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8857 - loss: 1.3849 - val_accuracy: 0.8669 - val_loss: 1.4361
# Epoch 7/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9203 - loss: 1.2512 - val_accuracy: 0.9531 - val_loss: 1.2671
# Epoch 8/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9449 - loss: 1.1334 - val_accuracy: 0.9440 - val_loss: 1.1856
# Epoch 9/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9538 - loss: 1.0501 - val_accuracy: 0.9435 - val_loss: 1.1122
# Epoch 10/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9588 - loss: 0.9837 - val_accuracy: 0.9579 - val_loss: 1.0333
# Epoch 11/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9635 - loss: 0.9249 - val_accuracy: 0.9464 - val_loss: 0.9864
# Epoch 12/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9662 - loss: 0.8709 - val_accuracy: 0.9794 - val_loss: 0.8911
# Epoch 13/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9687 - loss: 0.8229 - val_accuracy: 0.9665 - val_loss: 0.8522
# Epoch 14/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9710 - loss: 0.7780 - val_accuracy: 0.9646 - val_loss: 0.8049
# Epoch 15/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9717 - loss: 0.7389 - val_accuracy: 0.9737 - val_loss: 0.7438
# Epoch 16/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9737 - loss: 0.7015 - val_accuracy: 0.9737 - val_loss: 0.7010
# Epoch 17/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9746 - loss: 0.6705 - val_accuracy: 0.9717 - val_loss: 0.6692
# Epoch 18/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9755 - loss: 0.6371 - val_accuracy: 0.9751 - val_loss: 0.6246
# Epoch 19/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9695 - loss: 0.6197 - val_accuracy: 0.9761 - val_loss: 0.5993
# Epoch 20/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9780 - loss: 0.5829 - val_accuracy: 0.9689 - val_loss: 0.5875
# Epoch 21/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9775 - loss: 0.5600 - val_accuracy: 0.9756 - val_loss: 0.5463
# Epoch 22/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9793 - loss: 0.5358 - val_accuracy: 0.9751 - val_loss: 0.5252
# Epoch 23/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9798 - loss: 0.5132 - val_accuracy: 0.9746 - val_loss: 0.5029
# Epoch 24/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9789 - loss: 0.4929 - val_accuracy: 0.9775 - val_loss: 0.4738
# Epoch 25/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9804 - loss: 0.4709 - val_accuracy: 0.9737 - val_loss: 0.4665
# Epoch 26/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9808 - loss: 0.4506 - val_accuracy: 0.9737 - val_loss: 0.4509
# Epoch 27/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9802 - loss: 0.4360 - val_accuracy: 0.9775 - val_loss: 0.4183
# Epoch 28/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9820 - loss: 0.4190 - val_accuracy: 0.9770 - val_loss: 0.4066
# Epoch 29/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9824 - loss: 0.4017 - val_accuracy: 0.9780 - val_loss: 0.3895
# Epoch 30/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9833 - loss: 0.3859 - val_accuracy: 0.9780 - val_loss: 0.3763
# Epoch 31/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9833 - loss: 0.3714 - val_accuracy: 0.9804 - val_loss: 0.3516
# Epoch 32/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9834 - loss: 0.3577 - val_accuracy: 0.9794 - val_loss: 0.3440
# Epoch 33/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9848 - loss: 0.3440 - val_accuracy: 0.9784 - val_loss: 0.3384
# Epoch 34/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9854 - loss: 0.3284 - val_accuracy: 0.9780 - val_loss: 0.3263
# Epoch 35/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9860 - loss: 0.3184 - val_accuracy: 0.9775 - val_loss: 0.3180
# Epoch 36/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9857 - loss: 0.3068 - val_accuracy: 0.9794 - val_loss: 0.3050
# Epoch 37/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9862 - loss: 0.2984 - val_accuracy: 0.9808 - val_loss: 0.2879
# Epoch 38/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9870 - loss: 0.2877 - val_accuracy: 0.9789 - val_loss: 0.2845
# Epoch 39/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9874 - loss: 0.2770 - val_accuracy: 0.9784 - val_loss: 0.2801
# Epoch 40/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9881 - loss: 0.2679 - val_accuracy: 0.9789 - val_loss: 0.2706
# Epoch 41/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9878 - loss: 0.2599 - val_accuracy: 0.9784 - val_loss: 0.2651
# Epoch 42/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9883 - loss: 0.2514 - val_accuracy: 0.9780 - val_loss: 0.2613
# Epoch 43/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9879 - loss: 0.2449 - val_accuracy: 0.9784 - val_loss: 0.2474
# Epoch 44/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9882 - loss: 0.2347 - val_accuracy: 0.9789 - val_loss: 0.2397
# Epoch 45/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9889 - loss: 0.2275 - val_accuracy: 0.9789 - val_loss: 0.2373
# Epoch 46/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9904 - loss: 0.2188 - val_accuracy: 0.9808 - val_loss: 0.2250
# Epoch 47/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9905 - loss: 0.2125 - val_accuracy: 0.9794 - val_loss: 0.2251
# Epoch 48/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9907 - loss: 0.2068 - val_accuracy: 0.9794 - val_loss: 0.2205
# Epoch 49/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9904 - loss: 0.2004 - val_accuracy: 0.9804 - val_loss: 0.2078
# Epoch 50/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9904 - loss: 0.1938 - val_accuracy: 0.9813 - val_loss: 0.2005
# Epoch 51/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9921 - loss: 0.1868 - val_accuracy: 0.9818 - val_loss: 0.1959
# Epoch 52/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9924 - loss: 0.1812 - val_accuracy: 0.9794 - val_loss: 0.1974
# Epoch 53/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9924 - loss: 0.1749 - val_accuracy: 0.9813 - val_loss: 0.1881
# Epoch 54/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9928 - loss: 0.1701 - val_accuracy: 0.9794 - val_loss: 0.1886
# Epoch 55/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9939 - loss: 0.1644 - val_accuracy: 0.9808 - val_loss: 0.1810
# Epoch 56/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9942 - loss: 0.1605 - val_accuracy: 0.9789 - val_loss: 0.1805
# Epoch 57/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9941 - loss: 0.1562 - val_accuracy: 0.9818 - val_loss: 0.1735
# Epoch 58/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9943 - loss: 0.1514 - val_accuracy: 0.9799 - val_loss: 0.1720
# Epoch 59/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9943 - loss: 0.1468 - val_accuracy: 0.9804 - val_loss: 0.1667
# Epoch 60/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9948 - loss: 0.1416 - val_accuracy: 0.9847 - val_loss: 0.1588
# Epoch 61/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9947 - loss: 0.1379 - val_accuracy: 0.9794 - val_loss: 0.1659
# Epoch 62/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9954 - loss: 0.1326 - val_accuracy: 0.9804 - val_loss: 0.1613
# Epoch 63/100
# 482/482 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9957 - loss: 0.1294 - val_accuracy: 0.9804 - val_loss: 0.1595
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 60.

# %% [markdown]
# ### 3.7 Evaluation

# %%
loss, acc = model.evaluate([X_test_pad, X_test_tfidf], y_test, verbose=1)
print(f"\nAkurasi Test (LSTM + TF-IDF): {acc:.4f}")
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9856 - loss: 0.1568
#
# Akurasi Test (LSTM + TF-IDF): 0.9856

# %%
y_pred_prob = model.predict([X_test_pad, X_test_tfidf])
y_pred = (y_pred_prob > 0.5).astype(int)

acc  = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec  = recall_score(y_test, y_pred, zero_division=0)
f1   = f1_score(y_test, y_pred, zero_division=0)

print("\n" + "="*40)
print("   DETAIL EVALUASI: LSTM + TF-IDF")
print("="*40)
print(f"Akurasi   : {acc:.4f}")
print(f"Presisi   : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"F1-Score  : {f1:.4f}")
print("="*40)
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
#
# ========================================
#    DETAIL EVALUASI: LSTM + TF-IDF
# ========================================
# Akurasi   : 0.9856
# Presisi   : 0.9182
# Recall    : 0.8957
# F1-Score  : 0.9068
# ========================================

# %% [markdown]
# #### 3.7.1 Training and Validation Loss

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss (LSTM)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 3.7.2 Confusion Matrix

# %%
# y_pred_prob = model.predict([X_test_pad, X_test_tfidf])
# y_pred = (y_pred_prob > 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Non-Hoax', 'Hoax'],
            yticklabels=['Non-Hoax', 'Hoax'])
plt.title('Confusion Matrix (LSTM)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

print(classification_report(y_test, y_pred, target_names=['Non-Hoax', 'Hoax']))
# Out:
#               precision    recall  f1-score   support
#
#     Non-Hoax       0.99      0.99      0.99      1926
#         Hoax       0.92      0.90      0.91       163
#
#     accuracy                           0.99      2089
#    macro avg       0.95      0.94      0.95      2089
# weighted avg       0.99      0.99      0.99      2089

# %% [markdown]
# ### 3.8 Save Model

# %%
os.makedirs("../models", exist_ok=True) 
model.save(MODEL_SAVE_PATH)
print("Model LSTM saved to:", MODEL_SAVE_PATH)
# Out:
# Model LSTM saved to: ../models/lstm_model_raw.keras

# %% [markdown]
# ### 3.9 Addition

# %%
best_epoch_index = np.argmin(history.history['val_loss'])
best_val_loss = history.history['val_loss'][best_epoch_index]

print(f"Model mulai menghafal sekitar epoch: {best_epoch_index + 1}")
print(f"Validation Loss terendah (Best Epoch): {best_val_loss:.4f}")
# Out:
# Model mulai menghafal sekitar epoch: 60
# Validation Loss terendah (Best Epoch): 0.1588
